# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Uploading Case_study File

# %%
df = pd.read_csv('C:/Users/Swetha B Singh/Downloads/Python ML/Project/ML case Study.csv',header=0)

# %%
df.head()
# Out:
#              College             City       Role  Previous CTC  \
# 0        SVNIT Surat          Asansol    Manager         55523
# 1         NIT Bhopal            Ajmer  Executive         57081
# 2       IEM, Kolkata  Rajpur Sonarpur  Executive         60347
# 3  KIIT, Bhubaneswar            Ajmer  Executive         49010
# 4                DTU         Durgapur  Executive         57879
#
#    Previous job change  Graduation Marks  EXP (Month)       CTC
# 0                    3                66          1.6  71406.58
# 1                    1                84          1.5  68005.87
# 2                    2                52          2.3  76764.02
# 3                    2                81          2.8  82092.39
# 4                    4                74          2.7  73878.10

# %% [markdown]
# ### Uploading Tier1/Tier2/Tier3 city Colleges CSV file

# %%
college = pd.read_csv('C:/Users/Swetha B Singh/Downloads/Python ML/Project/Colleges.csv',header=0)

# %%
college.head()
# Out:
#           Tier 1          Tier 2                                      Tier 3
# 0     IIT Bombay  IIIT Bangalore  Ramaiah Institute of Technology, Bengaluru
# 1      IIT Delhi      IIIT Delhi                      TIET/Thapar University
# 2  IIT Kharagpur          IGDTUW                         Manipal Main Campus
# 3     IIT Madras     NIT Calicut                                 VIT Vellore
# 4     IIT Kanpur   IIITM Gwalior                             SRM Main Campus

# %% [markdown]
# #### Creating each Tier1/Tier2/Tier3 range to List

# %%
Tier1 = college["Tier 1"].tolist()
Tier2 = college["Tier 2"].tolist()
Tier3 = college["Tier 3"].tolist()

# %%
Tier1
# Out:
# ['IIT Bombay',
#  'IIT Delhi',
#  'IIT Kharagpur',
#  'IIT Madras',
#  'IIT Kanpur',
#  'IIT Roorkee',
#  'IIT Guwahati',
#  'IIIT Hyderabad',
#  'BITS Pilani (Pilani Campus)',
#  'IIT Indore',
#  'IIT Ropar',
#  'IIT BHU (Varanasi)',
#  'IIT ISM Dhanbad',
#  'DTU',
#  'NSUT Delhi (NSIT)',
#  'NIT Tiruchipally (Trichy)',
#  'NIT Warangal',
#  'NIT Surathkal (Karnataka)',
#  'Jadavpur University',
#  'BITS Pilani (Hyderabad Campus)',
#  'BITS Pilani (Goa Campus)',
#  'IIIT Allahabad',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
Tier2
# Out:
# ['IIIT Bangalore',
#  'IIIT Delhi',
#  'IGDTUW',
#  'NIT Calicut',
#  'IIITM Gwalior',
#  'IIIT Lucknow',
#  'MNNIT Allahabad',
#  'Punjab Engineering College',
#  'DAIICT',
#  'MNIT Jaipur',
#  'NIT Durgapur',
#  'VNIT Nagpur',
#  'LNMIIT',
#  'BIT Mesra',
#  'SVNIT Surat',
#  'NIT Jalandhar',
#  'NIT Jamshedpur',
#  'NIT Kurukshetra',
#  'NIT Patna',
#  'NIT Raipur',
#  'NIT Bhopal',
#  'NIT Rourkela',
#  'NIT Silchar',
#  'NIT Sikkim',
#  'IIIT Jabalpur',
#  'Jalpaiguri Government Engineering College',
#  'IIEST/BESU Shibpur',
#  'R.V. College of Engineering']

# %%
Tier3
# Out:
# ['Ramaiah Institute of Technology, Bengaluru',
#  'TIET/Thapar University',
#  'Manipal Main Campus',
#  'VIT Vellore',
#  'SRM Main Campus',
#  'KIIT, Bhubaneswar',
#  'Amity University',
#  'BMS College, Bangalore',
#  'PES University, Bangalore',
#  'USIT, Delhi',
#  'MAIT, Delhi',
#  'MSIT, Delhi',
#  'Dayanand College of Engineering, Bangalore',
#  'Heritage Institute of Technology, Kolkata',
#  'IEM, Kolkata',
#  'Techno India, Kolkata',
#  'Jaypee, Noida',
#  'Amrita University, Coimbatore',
#  'Cummins College of Engineering for Women, Pune',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %% [markdown]
# #### Converting List to Values in case_study file

# %%
for item in df.College:
    if item in Tier1:
        df["College"].replace(item,1,inplace=True)
    elif item in Tier2:
        df["College"].replace(item,2,inplace=True)
    elif item in Tier3:
        df["College"].replace(item,3,inplace=True)

# %%
df.head()
# Out:
#    College             City       Role  Previous CTC  Previous job change  \
# 0        2          Asansol    Manager         55523                    3
# 1        2            Ajmer  Executive         57081                    1
# 2        3  Rajpur Sonarpur  Executive         60347                    2
# 3        3            Ajmer  Executive         49010                    2
# 4        1         Durgapur  Executive         57879                    4
#
#    Graduation Marks  EXP (Month)       CTC
# 0                66          1.6  71406.58
# 1                84          1.5  68005.87
# 2                52          2.3  76764.02
# 3                81          2.8  82092.39
# 4                74          2.7  73878.10

# %% [markdown]
# ### Uploading Metro and NonMetro city CSV file

# %%
cities = pd.read_csv('C:/Users/Swetha B Singh/Downloads/Python ML/Project/cities.csv',header=0)

# %%
cities.head()
# Out:
#   Metrio City non-metro cities
# 0      Mumbai         Dehradun
# 1       Delhi         Durgapur
# 2     Kolkata          Asansol
# 3     Chennai         Rourkela
# 4   Bangalore        Kozhikode

# %% [markdown]
# ### Creating each Metro and NonMetro cities range to List

# %%
Metro = cities["Metrio City"].tolist()
Non_Metro = cities["non-metro cities"].tolist()

# %%
Metro
# Out:
# ['Mumbai',
#  'Delhi',
#  'Kolkata',
#  'Chennai',
#  'Bangalore',
#  'Hyderabad',
#  'Ahmedabad',
#  'Pune',
#  'Surat']

# %% [markdown]
# ### Converting List to Values in case_study file

# %%
for item in df.City:
    if item in Metro:
        df["City"].replace(item,1,inplace=True)
    elif item in Non_Metro:
        df["City"].replace(item,2,inplace=True)

# %%
df.head()
# Out:
#    College  City       Role  Previous CTC  Previous job change  \
# 0        2     2    Manager         55523                    3
# 1        2     2  Executive         57081                    1
# 2        3     2  Executive         60347                    2
# 3        3     2  Executive         49010                    2
# 4        1     2  Executive         57879                    4
#
#    Graduation Marks  EXP (Month)       CTC
# 0                66          1.6  71406.58
# 1                84          1.5  68005.87
# 2                52          2.3  76764.02
# 3                81          2.8  82092.39
# 4                74          2.7  73878.10

# %%
case_study=pd.DataFrame(df)

# %%
case_study.rename(columns={'EXP (Month)':'EXP_Month'},inplace=True)

# %%
case_study.head()
# Out:
#    College  City       Role  Previous CTC  Previous job change  \
# 0        2     2    Manager         55523                    3
# 1        2     2  Executive         57081                    1
# 2        3     2  Executive         60347                    2
# 3        3     2  Executive         49010                    2
# 4        1     2  Executive         57879                    4
#
#    Graduation Marks  EXP_Month       CTC
# 0                66        1.6  71406.58
# 1                84        1.5  68005.87
# 2                52        2.3  76764.02
# 3                81        2.8  82092.39
# 4                74        2.7  73878.10

# %%
case_study.describe()
# Out:
#            College         City  Previous CTC  Previous job change  \
# count  1589.000000  1589.000000   1589.000000          1589.000000
# mean      1.975456     1.485840  55518.453744             2.528634
# std       0.838330     0.499957   6655.218445             1.123918
# min       1.000000     1.000000  36990.000000             1.000000
# 25%       1.000000     1.000000  50518.000000             2.000000
# 50%       2.000000     1.000000  55291.000000             3.000000
# 75%       3.000000     2.000000  60109.000000             4.000000
# max       3.000000     2.000000  77911.000000             4.000000
#
#        Graduation Marks    EXP_Month            CTC
# count       1589.000000  1589.000000    1589.000000
# mean          59.855255     3.261863   75353.278798
# std           14.935139     1.175712   12587.288237
# min           35.000000     1.500000   53020.320000
# 25%           46.000000     2.200000   66902.350000
# ...

# %%
case_study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   College              1589 non-null   int64
#  1   City                 1589 non-null   int64
#  2   Role                 1589 non-null   object
#  3   Previous CTC         1589 non-null   int64
#  4   Previous job change  1589 non-null   int64
#  5   Graduation Marks     1589 non-null   int64
#  6   EXP_Month            1589 non-null   float64
#  7   CTC                  1589 non-null   float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 99.4+ KB

# %% [markdown]
# ## Creating Dummy Variables

# %%
case_study =pd.get_dummies(case_study)

# %%
case_study.replace({False:0,True:1},inplace=True)

# %%
case_study.head()
# Out:
#    College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0        2     2         55523                    3                66
# 1        2     2         57081                    1                84
# 2        3     2         60347                    2                52
# 3        3     2         49010                    2                81
# 4        1     2         57879                    4                74
#
#    EXP_Month       CTC  Role_Executive  Role_Manager
# 0        1.6  71406.58               0             1
# 1        1.5  68005.87               1             0
# 2        2.3  76764.02               1             0
# 3        2.8  82092.39               1             0
# 4        2.7  73878.10               1             0

# %% [markdown]
# ### Visualization Graphs

# %%
sns.jointplot(x=("EXP_Month"),y="CTC",data=case_study)

# %%
sns.jointplot(x="Graduation Marks",y="CTC",data=case_study)

# %%
sns.jointplot(x="Previous CTC",y="CTC",data=case_study)

# %%
sns.pairplot(case_study)
# Out:
# C:\Users\Swetha B Singh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Correlation Analysis

# %%
case_study.corr()
# Out:
#                       College      City  Previous CTC  Previous job change  \
# College              1.000000  0.014946      0.041979            -0.055060
# City                 0.014946  1.000000     -0.004644            -0.051670
# Previous CTC         0.041979 -0.004644      1.000000             0.005756
# Previous job change -0.055060 -0.051670      0.005756             1.000000
# Graduation Marks     0.003539  0.018616     -0.032976             0.019267
# EXP_Month            0.011828  0.024578      0.118202             0.023177
# CTC                 -0.029592  0.020365      0.258000             0.011370
# Role_Executive       0.014749 -0.048671     -0.012321             0.017150
# Role_Manager        -0.014749  0.048671      0.012321            -0.017150
#
#                      Graduation Marks  EXP_Month       CTC  Role_Executive  \
# College                      0.003539   0.011828 -0.029592        0.014749
# ...

# %%
x=case_study.drop("CTC",axis=1)
x.head()
# Out:
#    College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0        2     2         55523                    3                66
# 1        2     2         57081                    1                84
# 2        3     2         60347                    2                52
# 3        3     2         49010                    2                81
# 4        1     2         57879                    4                74
#
#    EXP_Month  Role_Executive  Role_Manager
# 0        1.6               0             1
# 1        1.5               1             0
# 2        2.3               1             0
# 3        2.8               1             0
# 4        2.7               1             0

# %%
y = case_study['CTC']
y.head()
# Out:
# 0    71406.58
# 1    68005.87
# 2    76764.02
# 3    82092.39
# 4    73878.10
# Name: CTC, dtype: float64

# %% [markdown]
# # Simple Regression Model

# %% [raw]
# In this Model we use two continous variable relationship to get straight line
# Steps
# 1.Analyze the correlation and directionality of the data.
# 2.Estimate the model by fitting the line.
# 3.Evaluate the validity and usefulness of the model.

# %%
import statsmodels.api as sn

# %%
lm=sn.OLS(case_study['EXP_Month'],x).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              EXP_Month   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.352e+28
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):               0.00
# Time:                        20:37:28   Log-Likelihood:                 45738.
# No. Observations:                1589   AIC:                        -9.146e+04
# Df Residuals:                    1581   BIC:                        -9.142e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.jointplot(x = case_study['EXP_Month'], y= case_study['CTC'], data=case_study, kind="reg")

# %% [markdown]
# # Splitting Train & Test DataSet

# %% [raw]
# A basic step in machine learning to evaluate the effectiveness of your model is to divide a dataset into training and test sets. A test set is meant to assess how well your model performs on data that it hasn't seen during training, which can help you predict how well it will perform on fresh, untested data.
#
# The split ratio that data scientists utilize the most frequently is 70:30 / 80:20
#
# In this model we have used test_size=0.2. Where 20% will be test set and 80% will be training set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1271, 8) (318, 8) (1271,) (318,)

# %%
from sklearn.linear_model import LinearRegression

# %%
simplelr = LinearRegression()

# %% [raw]
# .fit() function
#
# A model can be trained on a dataset using Python's.fit() function. After receiving the dataset as input, the function outputs a trained model. After training, the model can be used to new data to provide predictions.

# %%
simplelr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = simplelr.predict(x_test)

# %%
y_pred
# Out:
# array([69256.6764011 , 64355.21929079, 63302.50967072, 72070.70518228,
#        76768.54609475, 89047.77291042, 69408.7616195 , 71650.43641121,
#        71096.68270005, 73845.57905886, 71777.8914919 , 78331.07674913,
#        85623.37153847, 78389.49935775, 77279.18423293, 93637.33363014,
#        66135.22558954, 68580.78413464, 66780.26592285, 81523.98228697,
#        91364.888233  , 96219.1542519 , 71424.58854852, 67664.34740289,
#        72765.38907574, 67959.59200229, 73695.01997932, 94071.91731856,
#        72188.52959921, 74623.852766  , 68721.04063386, 69696.7778082 ,
#        85255.41387005, 80039.97047119, 98511.12042383, 79848.10768455,
#        71501.96858902, 81056.6757776 , 73571.97916098, 65993.54247627,
#        71499.24700481, 87955.89504673, 73248.35021394, 67882.78908116,
#        74984.15254822, 78371.64634627, 86680.67915845, 67814.35132809,
#        69539.5427941 , 76678.50878932, 90244.57530494, 69770.86448994,
# ...

# %%
y_test
# Out:
# 900     67487.61
# 427     72477.67
# 219     75535.50
# 1101    82986.23
# 748     73093.09
#           ...
# 379     94600.05
# 963     77795.84
# 878     79412.09
# 442     53020.32
# 231     66774.11
# Name: CTC, Length: 318, dtype: float64

# %%
print(simplelr.intercept_)
# Out:
# 48413.28497076183

# %% [markdown]
# ## Multiple Linear Regression Model

# %% [markdown]
# ### It is a model where we analysis the single dependent variable with multiple independent variable

# %%
x_multi=case_study.drop("CTC",axis=1)

# %%
x_multi.head()
# Out:
#    College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0        2     2         55523                    3                66
# 1        2     2         57081                    1                84
# 2        3     2         60347                    2                52
# 3        3     2         49010                    2                81
# 4        1     2         57879                    4                74
#
#    EXP_Month  Role_Executive  Role_Manager
# 0        1.6               0             1
# 1        1.5               1             0
# 2        2.3               1             0
# 3        2.8               1             0
# 4        2.7               1             0

# %%
x_multi.shape
# Out:
# (1589, 8)

# %%
y_multi = case_study['CTC']

# %%
y_multi.head()
# Out:
# 0    71406.58
# 1    68005.87
# 2    76764.02
# 3    82092.39
# 4    73878.10
# Name: CTC, dtype: float64

# %%
y_multi.shape
# Out:
# (1589,)

# %%
x_multi_cons = sn.add_constant(x_multi)

# %%
x_multi_cons.head()
# Out:
#    const  College  City  Previous CTC  Previous job change  Graduation Marks  \
# 0    1.0        2     2         55523                    3                66
# 1    1.0        2     2         57081                    1                84
# 2    1.0        3     2         60347                    2                52
# 3    1.0        3     2         49010                    2                81
# 4    1.0        1     2         57879                    4                74
#
#    EXP_Month  Role_Executive  Role_Manager
# 0        1.6               0             1
# 1        1.5               1             0
# 2        2.3               1             0
# 3        2.8               1             0
# 4        2.7               1             0

# %%
mlr_multi = sn.OLS(y_multi,x_multi_cons).fit()

# %%
mlr_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    CTC   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     258.8
# Date:                Tue, 31 Oct 2023   Prob (F-statistic):          8.81e-257
# Time:                        20:38:11   Log-Likelihood:                -16648.
# No. Observations:                1589   AIC:                         3.331e+04
# Df Residuals:                    1581   BIC:                         3.336e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
mlr = LinearRegression()

# %%
mlr.fit(x_multi,y_multi)
# Out:
# LinearRegression()

# %%
## Intercept_ attribute=Beta 0 and coef_ attribute = Beta 1,2,3,

# %%
print(mlr.coef_) ##coef_ attribute = Beta 1,2,3,
# Out:
# [-4.81877187e+02 -3.87505011e+02  4.10794884e-01  1.27457180e+02
#   6.59613420e+00  3.12924310e+03 -9.74268937e+03  9.74268937e+03]

# %%
print(mlr.intercept_) ## Intercept_ attribute=Beta 0
# Out:
# 48870.546650207165

# %%
mlr.predict(x_multi)
# Out:
# array([85507.54134849, 66213.07278631, 69492.62705816, ...,
#        62236.05515023, 67461.52577825, 81052.90839823])

# %% [markdown]
# # r2_score

# %% [raw]
# Regression models are evaluated using a statistic called the R2 score.
# R2 can have a value between 0 and 1,
# where 0 means that there is no possible explanation of the response variable by the predictor variable.
# Where 1 means that the predictor variables can explain it exactly and error-free.

# %%
from sklearn.metrics import r2_score

# %%
lm_a=LinearRegression()

# %%
lm_a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a=lm_a.predict(x_test)

# %%
y_train_a=lm_a.predict(x_train)

# %%
y_test_a
# Out:
# array([69256.6764011 , 64355.21929079, 63302.50967072, 72070.70518228,
#        76768.54609475, 89047.77291042, 69408.7616195 , 71650.43641121,
#        71096.68270005, 73845.57905886, 71777.8914919 , 78331.07674913,
#        85623.37153847, 78389.49935775, 77279.18423293, 93637.33363014,
#        66135.22558954, 68580.78413464, 66780.26592285, 81523.98228697,
#        91364.888233  , 96219.1542519 , 71424.58854852, 67664.34740289,
#        72765.38907574, 67959.59200229, 73695.01997932, 94071.91731856,
#        72188.52959921, 74623.852766  , 68721.04063386, 69696.7778082 ,
#        85255.41387005, 80039.97047119, 98511.12042383, 79848.10768455,
#        71501.96858902, 81056.6757776 , 73571.97916098, 65993.54247627,
#        71499.24700481, 87955.89504673, 73248.35021394, 67882.78908116,
#        74984.15254822, 78371.64634627, 86680.67915845, 67814.35132809,
#        69539.5427941 , 76678.50878932, 90244.57530494, 69770.86448994,
# ...

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.5327702608639138

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.5352211350587468

# %% [markdown]
# # Decision Tree Model

# %% [raw]
# Decison Tree is used in both classification and regression model.
# It is a non-parametric supervised learning algorithm.
# It draws a chart like a flowchart.

# %%
### max_depth = no of layers in a tree, layer should be upto 5
from sklearn import tree
decisiontree = tree.DecisionTreeRegressor(max_depth = 3)

# %%
decisiontree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# #### Predict values using trained model

# %%
y_train_pred = decisiontree.predict(x_train)
y_test_pred = decisiontree.predict(x_test)

# %%
y_test_pred
# Out:
# array([ 73854.40743842,  67137.92249315,  67137.92249315,  73854.40743842,
#         73854.40743842,  87264.44514286,  70080.03361607,  73854.40743842,
#         67137.92249315,  73854.40743842,  70080.03361607,  77399.07223256,
#         95311.75026316,  77399.07223256,  73854.40743842, 104985.9661039 ,
#         67137.92249315,  67137.92249315,  67137.92249315,  77399.07223256,
#        104985.9661039 , 104985.9661039 ,  67137.92249315,  67137.92249315,
#         70080.03361607,  67137.92249315,  77399.07223256, 104985.9661039 ,
#         73854.40743842,  73854.40743842,  67137.92249315,  67137.92249315,
#         77180.13443038,  77399.07223256, 104985.9661039 ,  73854.40743842,
#         67137.92249315,  77180.13443038,  67137.92249315,  67137.92249315,
#         67137.92249315,  77180.13443038,  73854.40743842,  67137.92249315,
#         77399.07223256,  70080.03361607,  77180.13443038,  67137.92249315,
# ...

# %% [markdown]
# ### Model Performance of Regression Model

# %%
### r2 lies b/w 0 and 1 - 1 is perfect fit & 0 means no fit not find any deviation, 0.4 to 0.8. for good model, 
###above 0.8 for excellent model##
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test,y_test_pred)
# Out:
# 59802220.24571091

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.6123081581939176

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.5969777445294466

# %% [markdown]
# ## Plotting Decision Tree

# %%
dot_data = tree.export_graphviz(decisiontree,out_file=None)

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [markdown]
# # Task Questions

# %% [markdown]
# 1. Your views about the problem statement?
#
# Ans : In this problem statement we can predict the salary based on Years of experience, Metro or Non-Metro Cities, Tier 1/2/3 colleges,previous_CTC and based on current running CTC.
#
# In this assignment i have used simple linear regression model
#
# I have compared with multiple linear regression model to show the coefficent and intercept.
#
# Python machine learning is frequently applied to useful problems, such as the salary prediction problem statement that uses simple linear regression. By using one or more predictor variables—such as years of experience, education, job role, and more.

# %% [markdown]
# 2. What will be your approach to solving this task?
#
# For Machine Learning we give a dataset to train and test where it can give the helpful response for both recuiter,
#
# To process the prediction on salary
#
# 1. Need a accuracy Data set which contain present data,historical data, quality and quantity that works on model.
# 2. Once we get the data we should do the data processing by handling missing values,outlier detection, normalization.
# 3. For better understanding we draw visulaization using scatter plots or linear line
# 4. Then we select which model will fit this problem.
# 5. After selecting model we will prdict the MSE(Mean Squared Error) and RMSE(Root Mean Squared Error).
# 6. Based on this we can create models like Multiple Linear Regression, K-nearestNeighbors(KNN),Linear Discriminant Analysis(LDA)    etc.,

# %% [markdown]
# 3. What were the available ML model options you had to perform this task?
#
# Ans: ML model which to perform is depend on the dataset and variables
#
# Linear Regression Model, Multiple Regrssion Model, k-Nearest Neighbour(k-NN), Gradient Boosting, Ridge and Lasso Regression, Ensemble Models, XG Boost , Decision Tree

# %% [markdown]
# 4. Which model’s performance is best and what could be the possible reason for that?
#
# Ans: For this assignment the best model is simple linear regression as the dependent variable is only one - (CTC)
#
# But, models can varies based on the dataset,feature evaluation metrics. The best models which can be used is Linear Regression, Decision tree,Multiple Linear Regression, Grandiant Boosting.

# %% [markdown]
# 5. What steps can you take to improve this selected model’s performance even further?
#
# Ans:
# Taking Input data
# Data Updating
# Based on input data, creating data processing, data cleaning, Predicting salary
# Generating data visualization
# Building new model for feature analysis
